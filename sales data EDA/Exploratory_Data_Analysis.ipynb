# %% [markdown]
# <a href="https://colab.research.google.com/github/UKJaagadhep/EDA/blob/main/Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# **Importing pandas and and reading the required csv file as a dataframe**

# %%
import pandas as pd
data=pd.read_csv("/content/Sales_April_2019.csv")
display(data)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %% [markdown]
# **Describing the dataframe**

# %%
display(data.describe())
# Out:
#         Order ID                   Product Quantity Ordered Price Each  \
# count      18324                     18324            18324      18324
# unique     17538                        20                8         19
# top     Order ID  Lightning Charging Cable                1      14.95
# freq          35                      2201            16558       2201
#
#         Order Date  Purchase Address
# count        18324             18324
# unique       13584             17120
# top     Order Date  Purchase Address
# freq            35                35

# %% [markdown]
# **Handling missing data**

# %% [markdown]
# 1) Drop NULL or missing values:

# %%
display(data.dropna())
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %% [markdown]
# 2) Fill missing values:

# %%
data['Order ID']=data['Order ID'].fillna(0)
data['Product']=data['Product'].fillna(0)
data['Quantity Ordered']=data['Quantity Ordered'].fillna(0)
data['Price Each']=data['Price Each'].fillna(0.0)
data['Order Date']=data['Order Date'].fillna(False)
data['Purchase Address']=data['Purchase Address'].fillna(False)
display(data)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1            0                           0                0        0.0
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %% [markdown]
# **Handling Outliers**

# %% [markdown]
# 1) Boxplot

# %%
import seaborn as sn
import matplotlib.pyplot as pyl
data["Price Each"]=pd.to_numeric(data["Price Each"],errors='coerce')
box_plot=sn.boxplot(data=data, x="Price Each")
pyl.show(box_plot)

# %% [markdown]
# 2) Scatterplot

# %%
data["Price Each"]=pd.to_numeric(data["Price Each"],errors='coerce')
data["Quantity Ordered"]=pd.to_numeric(data["Quantity Ordered"], errors='coerce')
scatter_plot=data.plot.scatter(x="Quantity Ordered",y="Price Each")
pyl.show(scatter_plot)

# %% [markdown]
# 3) Z-Score

# %%
import numpy as np
import scipy.stats as sp
numpy_array = np.array(data["Price Each"])
numpy_array = numpy_array[~np.isnan(numpy_array)]
z_score=sp.zscore(numpy_array)
zscores=pd.Series(z_score)
display(zscores)
# Out:
# 0       -0.520027
# 1       -0.556180
# 2       -0.253672
# 3        1.259049
# 4       -0.519906
#            ...
# 18343    1.259049
# 18344   -0.544563
# 18345   -0.547134
# 18346   -0.544563
# 18347   -0.510951
# Length: 18348, dtype: float64

# %%
#Outliers
data_z=data.dropna()[z_score>=3]
display(data_z)
# Out:
#       Order ID             Product  Quantity Ordered  Price Each  \
# 9       176565  Macbook Pro Laptop               1.0      1700.0
# 86      176639  Macbook Pro Laptop               1.0      1700.0
# 90      176643  Macbook Pro Laptop               1.0      1700.0
# 93      176646  Macbook Pro Laptop               1.0      1700.0
# 136     176687  Macbook Pro Laptop               1.0      1700.0
# ...        ...                 ...               ...         ...
# 18111   193839  Macbook Pro Laptop               1.0      1700.0
# 18161   193885  Macbook Pro Laptop               1.0      1700.0
# 18173   193897  Macbook Pro Laptop               1.0      1700.0
# 18254   193972  Macbook Pro Laptop               1.0      1700.0
# 18303   194019  Macbook Pro Laptop               1.0      1700.0
#
#            Order Date                        Purchase Address
# 9      04/24/19 10:38  915 Willow St, San Francisco, CA 94016
# ...

# %%
#Without outliers
data=data.dropna()[z_score<3]
display(data)
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       176558        USB-C Charging Cable               2.0       11.95
# 1            0                           0               0.0        0.00
# 2       176559  Bose SoundSport Headphones               1.0       99.99
# 3       176560                Google Phone               1.0      600.00
# 4       176560            Wired Headphones               1.0       11.99
# ...        ...                         ...               ...         ...
# 18378   194090                Google Phone               1.0      600.00
# 18379   194091       AA Batteries (4-pack)               1.0        3.84
# 18380   194092      AAA Batteries (4-pack)               2.0        2.99
# 18381   194093       AA Batteries (4-pack)               1.0        3.84
# 18382   194094    Lightning Charging Cable               1.0       14.95
#
#            Order Date                        Purchase Address
# ...

# %% [markdown]
# 4) IQR

# %%
q1=data["Price Each"].quantile(0.25)
q3=data["Price Each"].quantile(0.75)
iqr=q3-q1
iqr_range_1=q1-1.5*iqr
iqr_range_2=q3+1.5*iqr

# %%
#data outlier
data_outlier=data[(data["Price Each"]<iqr_range_1) | (data["Price Each"]>iqr_range_2)]
display(data_outlier)
# Out:
#       Order ID                 Product  Quantity Ordered  Price Each  \
# 3       176560            Google Phone               1.0      600.00
# 11      176567            Google Phone               1.0      600.00
# 13      176569  27in 4K Gaming Monitor               1.0      389.99
# 18      176574            Google Phone               1.0      600.00
# 26      176581                  iPhone               1.0      700.00
# ...        ...                     ...               ...         ...
# 18351   194063  27in 4K Gaming Monitor               1.0      389.99
# 18355   194067                  iPhone               1.0      700.00
# 18360   194072  34in Ultrawide Monitor               1.0      379.99
# 18374   194086            Google Phone               1.0      600.00
# 18378   194090            Google Phone               1.0      600.00
#
#            Order Date                          Purchase Address
# 3      04/12/19 14:38      669 Spruce St, Los Angeles, CA 90001
# ...

# %%
#dataframe after handling outliers
data=data[(data["Price Each"]>=iqr_range_1) & (data["Price Each"]<=iqr_range_2)]
display(data)
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       176558        USB-C Charging Cable               2.0       11.95
# 1            0                           0               0.0        0.00
# 2       176559  Bose SoundSport Headphones               1.0       99.99
# 4       176560            Wired Headphones               1.0       11.99
# 5       176561            Wired Headphones               1.0       11.99
# ...        ...                         ...               ...         ...
# 18377   194089        USB-C Charging Cable               1.0       11.95
# 18379   194091       AA Batteries (4-pack)               1.0        3.84
# 18380   194092      AAA Batteries (4-pack)               2.0        2.99
# 18381   194093       AA Batteries (4-pack)               1.0        3.84
# 18382   194094    Lightning Charging Cable               1.0       14.95
#
#            Order Date                        Purchase Address
# ...

# %% [markdown]
# **Understanding relationships and new insights through plots**

# %% [markdown]
# 1) Histogram

# %%
hist_plot=sn.histplot(data=data,x='Quantity Ordered')
pyl.show(hist_plot)

# %% [markdown]
# 2) Heat map

# %%
data_hmap=pd.concat((data["Price Each"],data["Product"]),axis=1)
data_hmap_1=data_hmap.set_index('Product')
sn.heatmap(data=data_hmap_1.head(50))
# Out:
# <Axes: ylabel='Product'>
