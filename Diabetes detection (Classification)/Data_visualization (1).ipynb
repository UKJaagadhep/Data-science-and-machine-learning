# %% [markdown]
# # **DATA VISUALIZATION**

# %%
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/diabetes.csv")
display(data)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
import numpy as np
print(np.mean(data['BMI']))
print(np.median(data['BMI']))
print(np.std(data['BMI']))
print(np.percentile(data['BMI'],np.arange(0,100,25)))
print(np.percentile(data['BMI'],66))
# Out:
# 31.992578124999998
# 32.0
# 7.87902573154013
# [ 0.  27.3 32.  36.6]
# 34.6

# %%
from statsmodels import robust
print(robust.mad(data['BMI']))
# Out:
# 6.819970205125771

# %%
data.plot.scatter(x='Pregnancies',y='DiabetesPedigreeFunction') #scatterplot using pandas
# Out:
# <Axes: xlabel='Pregnancies', ylabel='DiabetesPedigreeFunction'>

# %%
plt.scatter(x=data['Pregnancies'], y=data['DiabetesPedigreeFunction']) #scatterplot using matplotlib
plt.xlabel("Pregnancies")
plt.ylabel("DiabetesPedigreeFunction")
# Out:
# Text(0, 0.5, 'DiabetesPedigreeFunction')

# %%
data.sample(100).plot.scatter(x='Pregnancies',y='DiabetesPedigreeFunction') #plots random 100 points
# Out:
# <Axes: xlabel='Pregnancies', ylabel='DiabetesPedigreeFunction'>

# %%
sns.scatterplot(data=data, x='Pregnancies', y='DiabetesPedigreeFunction') #scatterplot using seaborn
# Out:
# <Axes: xlabel='Pregnancies', ylabel='DiabetesPedigreeFunction'>

# %%
data_new = data.groupby('Pregnancies').median().reset_index()
display(data_new)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0             0    119.0           70.0           25.0     36.0  34.60
# 1             1    109.0           68.0           24.0     67.0  30.10
# 2             2    108.0           66.0           22.0     63.0  30.40
# 3             3    116.0           70.0           22.0     70.0  31.00
# 4             4    123.0           71.0           16.0      0.0  32.00
# 5             5    116.0           75.0           22.0      0.0  33.70
# 6             6    114.5           72.0           21.0      0.0  30.40
# 7             7    136.0           76.0           25.0      0.0  32.80
# 8             8    122.0           76.0           19.5      0.0  32.55
# 9             9    132.0           78.0           24.5      0.0  32.15
# 10           10    118.5           73.0            9.0      0.0  31.80
# 11           11    135.0           76.0           28.0      0.0  36.60
# ...

# %%
data_new.plot.line(x='Pregnancies', y='BloodPressure') #pandas line plot
# Out:
# <Axes: xlabel='Pregnancies'>

# %%
data_new.plot.line(x='Pregnancies') #pandas line plot with all other coloumns than x columns as y columns with each graph for each one
# Out:
# <Axes: xlabel='Pregnancies'>

# %%
plt.plot(data_new['Pregnancies'], data_new['BloodPressure'])

# %%
sns.lineplot(data=data_new, x='Pregnancies', y='BloodPressure')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='BloodPressure'>

# %%
data_new.plot.bar(x='Pregnancies', y='BMI')
# Out:
# <Axes: xlabel='Pregnancies'>

# %%
plt.bar(data_new['Pregnancies'], data_new['BMI'])
# Out:
# <BarContainer object of 17 artists>

# %%
sns.barplot(data=data_new, x='Pregnancies', y='BMI')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='BMI'>

# %%
data_new.plot.barh(x='Pregnancies', y='BMI')
# Out:
# <Axes: ylabel='Pregnancies'>

# %%
plt.barh(data_new['Pregnancies'], data_new['BMI'])
# Out:
# <BarContainer object of 17 artists>

# %%
sns.barplot(data=data_new, x='BMI', y='Pregnancies', orient='h')
# Out:
# <Axes: xlabel='BMI', ylabel='Pregnancies'>

# %%
data['Glucose'].hist()
# Out:
# <Axes: >

# %%
plt.hist(data['Glucose'])
# Out:
# (array([  5.,   0.,   4.,  32., 156., 211., 163.,  95.,  56.,  46.]),
#  array([  0. ,  19.9,  39.8,  59.7,  79.6,  99.5, 119.4, 139.3, 159.2,
#         179.1, 199. ]),
#  <BarContainer object of 10 artists>)

# %%
data['Pregnancies'].value_counts()
# Out:
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: Pregnancies, dtype: int64

# %%
data['Glucose'].hist(bins=5)
# Out:
# <Axes: >

# %%
plt.hist(data['Glucose'], bins=5)
# Out:
# (array([  5.,  36., 367., 258., 102.]),
#  array([  0. ,  39.8,  79.6, 119.4, 159.2, 199. ]),
#  <BarContainer object of 5 artists>)

# %%
sns.histplot(data=data, x='Glucose')
# Out:
# <Axes: xlabel='Glucose', ylabel='Count'>

# %%
sns.histplot(data=data, x='Glucose', bins=3)
plt.savefig('a.svg')

# %% [markdown]
# Histograms are used in anomaly detection

# %% [markdown]
# 3D **REPRESENTATION**

# %%
data.plot.scatter(x='Pregnancies', y='DiabetesPedigreeFunction', c='Outcome')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='DiabetesPedigreeFunction'>

# %%
data['color_scheme'] = data['Outcome'].apply(lambda x: 'red' if x==0 else 'green')
data.plot.scatter(x='Pregnancies', y='DiabetesPedigreeFunction', c='color_scheme')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='DiabetesPedigreeFunction'>

# %%
for i in [0,1]:
  c='red' if i==0 else 'green'
  var_i = data[data['Outcome']==i]
  plt.scatter(var_i['Pregnancies'], var_i['DiabetesPedigreeFunction'], color=c )

# %%
sns.scatterplot(data=data, x= 'Pregnancies', y= 'DiabetesPedigreeFunction', hue='Outcome')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='DiabetesPedigreeFunction'>

# %%
sns.scatterplot(data=data, x= 'Pregnancies', y= 'DiabetesPedigreeFunction', hue='Glucose')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='DiabetesPedigreeFunction'>

# %%
data.plot.scatter(x='Pregnancies', y='DiabetesPedigreeFunction', c='Glucose')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='DiabetesPedigreeFunction'>

# %%
sns.relplot(data=data, x='BloodPressure', y='BMI', row='Outcome', col='Pregnancies', height=3, aspect=1)

# %%
sns.relplot(data=data, x='BloodPressure', y='BMI', row='Outcome', col='Pregnancies', height=2, aspect=1, kind='line')

# %%
sns.pairplot(data)

# %%
fig,axes=plt.subplots(3,2)
#see about subplots

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome', 'color_scheme'],
#       dtype='object')

# %%
data['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
sns.set_style("whitegrid")
g=sns.FacetGrid(data, hue='BMI', col='Outcome')
g.map(plt.scatter, 'Age', 'Glucose')
g.add_legend()

# %%
sns.distplot( x=data['BMI'])
# Out:
# <ipython-input-50-94d5443a1d55>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( x=data['BMI'])
# <Axes: ylabel='Density'>

# %%
sns.histplot( x=data['BMI'], kde=True)
# Out:
# <Axes: xlabel='BMI', ylabel='Count'>

# %%
import numpy as np
count, bin_edge = np.histogram(data['Age'],bins=5, density=False)
print(count)
print(bin_edge)
# Out:
# [457 178  86  42   5]
# [21. 33. 45. 57. 69. 81.]

# %%
import numpy as np
count, bin_edge = np.histogram(data['Age'],bins=20, density=True)
print(count)
print(bin_edge)
pdf = count/sum(count)
print(pdf)
cdf=np.cumsum(pdf)
print(cdf)
# Out:
# [0.07508681 0.05512153 0.04166667 0.02647569 0.01779514 0.02213542
#  0.02039931 0.01692708 0.01475694 0.0078125  0.00911458 0.00564236
#  0.00651042 0.00477431 0.00347222 0.00347222 0.00130208 0.00043403
#  0.         0.00043403]
# [21. 24. 27. 30. 33. 36. 39. 42. 45. 48. 51. 54. 57. 60. 63. 66. 69. 72.
#  75. 78. 81.]
# [0.22526042 0.16536458 0.125      0.07942708 0.05338542 0.06640625
#  0.06119792 0.05078125 0.04427083 0.0234375  0.02734375 0.01692708
#  0.01953125 0.01432292 0.01041667 0.01041667 0.00390625 0.00130208
#  0.         0.00130208]
# [0.22526042 0.390625   0.515625   0.59505208 0.6484375  0.71484375
#  0.77604167 0.82682292 0.87109375 0.89453125 0.921875   0.93880208
#  0.95833333 0.97265625 0.98307292 0.99348958 0.99739583 0.99869792
#  0.99869792 1.        ]

# %%
plt.plot(bin_edge[1:],pdf)

# %%
plt.plot(bin_edge[1:],cdf)

# %%
sns.boxplot(data=data, y='BMI', x='Outcome')
# Out:
# <Axes: xlabel='Outcome', ylabel='BMI'>

# %%
sns.violinplot(data=data, x = 'Outcome', y = 'BMI')
# Out:
# <Axes: xlabel='Outcome', ylabel='BMI'>
